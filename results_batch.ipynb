# %%
import numpy as np
import pandas as pd
import pyswarms as ps
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import PSONN
import classicNN
from commonsetup import PreprocessData

# %%
iris=PreprocessData('iris')

iris_nn_result=classicNN.run(iris)
# Out:
# == Loading Iris Data ...
# == [ 150 Instances, 4 Dimensions, 3 classes ]
# == ===========================================
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Epoch 0, Loss: 1.0985
# Epoch 100, Loss: 1.0983
# Epoch 200, Loss: 1.0980
# Epoch 300, Loss: 1.0977
# Epoch 400, Loss: 1.0974
# Epoch 500, Loss: 1.0971
# Epoch 600, Loss: 1.0967
# Epoch 700, Loss: 1.0963
# Epoch 800, Loss: 1.0959
# Epoch 900, Loss: 1.0953
# Epoch 1000, Loss: 1.0946
# Epoch 1100, Loss: 1.0938
# Epoch 1200, Loss: 1.0928
# Epoch 1300, Loss: 1.0916
# Epoch 1400, Loss: 1.0900
# Epoch 1500, Loss: 1.0882
# Epoch 1600, Loss: 1.0860
# Epoch 1700, Loss: 1.0833
# Epoch 1800, Loss: 1.0801
# Epoch 1900, Loss: 1.0764
# Epoch 2000, Loss: 1.0721
# Epoch 2100, Loss: 1.0672
# Epoch 2200, Loss: 1.0616
# Epoch 2300, Loss: 1.0556
# Epoch 2400, Loss: 1.0489
# Epoch 2500, Loss: 1.0417
# Epoch 2600, Loss: 1.0340
# Epoch 2700, Loss: 1.0256
# Epoch 2800, Loss: 1.0165
# Epoch 2900, Loss: 1.0066
# Epoch 3000, Loss: 0.9959
# Epoch 3100, Loss: 0.9841
# Epoch 3200, Loss: 0.9711
# Epoch 3300, Loss: 0.9570
# Epoch 3400, Loss: 0.9420
# Epoch 3500, Loss: 0.9275
# Epoch 3600, Loss: 0.9135
# Epoch 3700, Loss: 0.8999
# Epoch 3800, Loss: 0.8867
# Epoch 3900, Loss: 0.8740
# Epoch 4000, Loss: 0.8618
# Epoch 4100, Loss: 0.8499
# Epoch 4200, Loss: 0.8384
# Epoch 4300, Loss: 0.8271
# Epoch 4400, Loss: 0.8158
# Epoch 4500, Loss: 0.8045
# Epoch 4600, Loss: 0.7931
# Epoch 4700, Loss: 0.7816
# Epoch 4800, Loss: 0.7698
# Epoch 4900, Loss: 0.7577
# Epoch 5000, Loss: 0.7452
# Epoch 5100, Loss: 0.7323
# Epoch 5200, Loss: 0.7190
# Epoch 5300, Loss: 0.7053
# Epoch 5400, Loss: 0.6913
# Epoch 5500, Loss: 0.6771
# Epoch 5600, Loss: 0.6628
# Epoch 5700, Loss: 0.6486
# Epoch 5800, Loss: 0.6346
# Epoch 5900, Loss: 0.6210
# Epoch 6000, Loss: 0.6078
# Epoch 6100, Loss: 0.5951
# Epoch 6200, Loss: 0.5830
# Epoch 6300, Loss: 0.5714
# Epoch 6400, Loss: 0.5604
# Epoch 6500, Loss: 0.5499
# Epoch 6600, Loss: 0.5400
# Epoch 6700, Loss: 0.5306
# Epoch 6800, Loss: 0.5217
# Epoch 6900, Loss: 0.5132
# Epoch 7000, Loss: 0.5051
# Epoch 7100, Loss: 0.4974
# Epoch 7200, Loss: 0.4900
# Epoch 7300, Loss: 0.4829
# Epoch 7400, Loss: 0.4761
# Epoch 7500, Loss: 0.4695
# Epoch 7600, Loss: 0.4632
# Epoch 7700, Loss: 0.4572
# Epoch 7800, Loss: 0.4513
# Epoch 7900, Loss: 0.4456
# Epoch 8000, Loss: 0.4400
# Epoch 8100, Loss: 0.4346
# Epoch 8200, Loss: 0.4294
# Epoch 8300, Loss: 0.4243
# Epoch 8400, Loss: 0.4193
# Epoch 8500, Loss: 0.4144
# Epoch 8600, Loss: 0.4096
# Epoch 8700, Loss: 0.4049
# Epoch 8800, Loss: 0.4002
# Epoch 8900, Loss: 0.3957
# Epoch 9000, Loss: 0.3912
# Epoch 9100, Loss: 0.3868
# Epoch 9200, Loss: 0.3825
# Epoch 9300, Loss: 0.3782
# Epoch 9400, Loss: 0.3739
# Epoch 9500, Loss: 0.3698
# Epoch 9600, Loss: 0.3656
# Epoch 9700, Loss: 0.3616
# Epoch 9800, Loss: 0.3575
# Epoch 9900, Loss: 0.3535
# Accuracy: 0.83

# %%
iris_params = {
    'c1': 3,
    'c2': 1,
    'w': 0.3,
    'velocity': (-0.5, 0.5),
    'swarm_size': 10,
    'batch_size': 20}

iris_pso_result = PSONN.run(iris, iris_params)
# Out:
# ############ you are using the following settings:
# Number hidden layers:  8
# activation:  <function relu at 0x000001FE16891C60>
# Number of variables to optimize:  67
# PSO parameters C1:  3 C2:  1 W:  0.3 Swarmsize:  10 Iteration:  10000
#
#
# Best Weights Found: [0.34959224 0.30120012 0.85120066 0.30726801 0.27776803 0.35673586
#  0.30886707 0.8580202  0.87981418 0.45428298]
# Accuracy PSO-NN: 0.93

# %%
print(pd.DataFrame(data={'Classic NN':[accuracy_score(iris_nn_result[0],iris_nn_result[1]),iris_nn_result[2],iris_nn_result[3]],
                            'PSO NN':[accuracy_score(iris_pso_result[1],iris_pso_result[2]),iris_pso_result[3],iris_pso_result[4]]},
                            index=['Accuracy','Train time','Fit time']))
iris_pso_result[0].visualize(iris_pso_result[1],iris_pso_result[2])
# Out:
#             Classic NN     PSO NN
# Accuracy      0.600000   0.933333
# Train time    1.714882  50.905620
# Fit time      0.000000   0.000997
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        11
#            1       1.00      0.85      0.92        13
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.93        30
#    macro avg       0.92      0.95      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %%
digits=PreprocessData('digits')

digits_nn_result=classicNN.run(digits)
# Out:
# == Loading Digits Data ...
# == [ 3823 Instances, 16 Dimensions, 10 classes ]
# == ===========================================
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Epoch 0, Loss: 2.3022
# Epoch 100, Loss: 2.2976
# Epoch 200, Loss: 2.2928
# Epoch 300, Loss: 2.2870
# Epoch 400, Loss: 2.2798
# Epoch 500, Loss: 2.2707
# Epoch 600, Loss: 2.2594
# Epoch 700, Loss: 2.2458
# Epoch 800, Loss: 2.2301
# Epoch 900, Loss: 2.2125
# Accuracy: 0.17

# %%
digits_params = {
    'c1': 1,
    'c2': 3,
    'w': 0.8,
    'velocity': (-2, 2),
    'swarm_size': 500,
    'batch_size': 500}

digits_pso_result = PSONN.run(digits, digits_params)
# Out:
# ############ you are using the following settings:
# Number hidden layers:  32
# activation:  <function relu at 0x000001E2D0461B20>
# Number of variables to optimize:  874
# PSO parameters C1:  1 C2:  3 W:  0.8 Swarmsize:  500 Iteration:  1000
#
#
# Best Weights Found: [ 3.16695089  2.70023136 -4.57131252  6.91129041 -3.59464856  4.11947228
#   3.51595042 -5.1886802  -1.41226455  5.51805766]
# Accuracy PSO-NN: 0.46

# %%
print(pd.DataFrame(data={'Classic NN':[accuracy_score(digits_nn_result[0],digits_nn_result[1]),digits_nn_result[2],digits_nn_result[3]],
                            'PSO NN':[accuracy_score(digits_pso_result[1],digits_pso_result[2]),digits_pso_result[3],digits_pso_result[4]]},
                            index=['Accuracy','Train time','Fit time']))
digits_pso_result[0].visualize(digits_pso_result[1],digits_pso_result[2])
# Out:
#             Classic NN      PSO NN
# Accuracy      0.169935    0.461438
# Train time    4.545753  238.354169
# Fit time      0.000000    0.008027
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.67      0.55        81
#            1       0.61      0.75      0.67        76
#            2       0.54      0.95      0.68        56
#            3       0.00      0.00      0.00        93
#            4       0.49      0.61      0.54        79
#            5       0.34      0.44      0.38        87
#            6       0.00      0.00      0.00        68
#            7       0.72      0.95      0.82        82
#            8       0.18      0.45      0.26        55
#            9       0.00      0.00      0.00        88
#
#     accuracy                           0.46       765
#    macro avg       0.33      0.48      0.39       765
# weighted avg       0.33      0.46      0.38       765
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
